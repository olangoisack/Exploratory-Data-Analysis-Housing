# %% [markdown]
# ## Python Operators

# %%
# Operators are special symbols in Python that perform operations on values(operands).
# Example

# %%
3 + 2 # 3 and 2 are operands
# + is the operator
# Out:
# 5

# %% [markdown]
# ### 1.Arithmetic Operators
# ### 2.Comparison Operators(Relational) Operators
# ### 3.Logical Operators
# ### 4.Assignment Operators
# ### 5.Bitwise Operators
# ### 6.Membership Operators
# ### 7.Identity Operators

# %% [markdown]
# # 1.Arithmetic Operators

# %%
# Used for mathematical operations.

# %%
2 + 3 # Addition
# Out:
# 5

# %%
10-3 #Subtraction
# Out:
# 7

# %%
10*3 #an asterisk is used for multiplication
# Out:
# 30

# %%
10/3  #Division gives a decimal number(float)
# Out:
# 3.3333333333333335

# %%
10//3 #floor division gives a whole number(int)
# Out:
# 3

# %% [markdown]
# ### Modulus(remainder)

# %%
10 % 3
# Out:
# 1

# %%
10 % 2
# Out:
# 0

# %%
10 ** 2 #Exponentiation shows power form
# Out:
# 100

# %% [markdown]
# # 2.Comparison Operators

# %%
#Used to compare values(results are True of False)

# %% [markdown]
# #### Equal(==)

# %%
5 == 5
# Out:
# True

# %%
5 == 4
# Out:
# False

# %% [markdown]
# #### Not Equal(!=)

# %%
2 == 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %% [markdown]
# ### Greater than

# %%
7 > 3
# Out:
# True

# %% [markdown]
# ### Less than

# %%
2 < 8
# Out:
# True

# %% [markdown]
# ### Greater than or equal

# %%
6>=6
# Out:
# True

# %% [markdown]
# ### Less than or equal

# %%
4 <= 5
# Out:
# True

# %% [markdown]
# # 3.Logical Operators

# %%
# Used to combine conditions

# %%
#we have three main logical operators and,or,not

# %% [markdown]
# # AND

# %%
5  >  2  and   10  > 3 #True if both are True
# Out:
# True

# %% [markdown]
# # OR

# %%
#It is True if atleast one is True

# %%
5 > 2   or   10 < 3
# Out:
# True

# %% [markdown]
# # NOT

# %%
#Negates the condition

# %%
5>2
# Out:
# True

# %%
not 5>2
# Out:
# False

# %% [markdown]
# # 4.Assignment Operators

# %%
#Used to assign values to variables

# %%
box_1 = 'biscuits' 
crate = 'mirinda'
#merchandise = president

print(box_1)
print(crate)
# Out:
# biscuits
# mirinda

# %% [markdown]
# ## =

# %% [markdown]
# # +=

# %%
a = 1
#a += 1     
a = a + 1
print(a)
# Out:
# 2

# %%
b = 1
b = b + 1
print(b)
# Out:
# 2

# %% [markdown]
# # -=

# %%
a = 1
#a -= 1
a = 1 -1
print(a)
# Out:
# 0

# %% [markdown]
# ## *=
# ## /=
# ## %=
# ## **=

# %%
c = 3
c *= 2

print(c)
# Out:
# 6

# %%
C=6
C*=2   
C = C * 2
print(C)
# Out:
# 12

# %%
d=10
d/=5
#d = d /5    d/=5
print(d)
# Out:
# 2.0

# %%
e=3
e**=2
print(e)
# Out:
# 9

# %%
a=2
b=4
a*=b
print(a)
# Out:
# 8

# %%
d = 4
d %= 3   
print(d)
# Out:
# 1
