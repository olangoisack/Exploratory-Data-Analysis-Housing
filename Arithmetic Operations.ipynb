# %% [markdown]
# # 1.Addition and subtraction

# %%
#Addition

print(10 + 5)
# Out:
# 15

# %%
10 + 5
# Out:
# 15

# %%
#Subtraction

10 - 5
# Out:
# 5

# %% [markdown]
# # 2.Multiplication

# %%
#Multiplication
# We use the asterisk key (usually shift + 8)

5 * 3
# Out:
# 15

# %%
print(5 * 4)
# Out:
# 20

# %% [markdown]
# # 3.Division(/)

# %%
# Division
print( 10 / 5)
# Out:
# 2.0

# %% [markdown]
# # 4.The Special Division Operator

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 / 2
# Out:
# 5.0

# %%
10 / 5 #Standard
# Out:
# 2.0

# %% [markdown]
# # Floor Division

# %%
10 // 3 #Floor
# Out:
# 3

# %%
10000 // 22222
# Out:
# 0

# %% [markdown]
# # 5.Modulus(%)

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
#10 slices of bread divided by 3 people
10 % 3 # this shows the remainder
# Out:
# 1

# %%
5 % 2
# Out:
# 1

# %%
# 12 divides perfectly by 4 , so the remainder is zero
print( 12 % 4)
# Out:
# 0

# %% [markdown]
# # Exponentiation

# %%
#This is the 'power of'
#We use two astersisks(**).Using one (*) is just multiplication.

2 ** 3
# Out:
# 8

# %%
2 * 2 * 2
# Out:
# 8

# %%
2 ** 4
# Out:
# 16

# %%
2 * 2 * 2 * 2
# Out:
# 16

# %%
2 ** 5
# Out:
# 32

# %%
2 * 2 * 2 * 2 * 2
# Out:
# 32

# %%
print(5 ** 2)
# Out:
# 25

# %% [markdown]
# # Order of Operation(Order of Precedence)

# %%
#Python follows standard mathematical rules(PEMDAS/BODMAS)

# %% [raw]
# ()-Parentheses
# []-Square brackets
# {}-Curly Brackets/braces
#
# 1.P-Parentheses
# 2.E-Exponents**
# 3.M-Multiplication
# 4.D-Division
# 5.A-Addition
# 6.S-Subtraction

# %%
10 + 5 * 2
# Out:
# 20

# %%
5 * 2
# Out:
# 10

# %%
10 + 10
# Out:
# 20

# %%
(10 + 5) * 2
# Out:
# 30

# %%
(10 + 5)
# Out:
# 15

# %%
15 * 2
# Out:
# 30

# %%
( 10 + 5) * 2 ** 2 / 2
# Out:
# 30.0

# %%
(10 + 5)
# Out:
# 15

# %%
15 * 2 ** 2 // 2
# Out:
# 30

# %%
2 ** 2
# Out:
# 4

# %%
15 * 4 / 2

# %%
15 * 4
# Out:
# 60

# %%
60 // 2
# Out:
# 30
