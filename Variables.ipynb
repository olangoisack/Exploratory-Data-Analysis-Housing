# %%
box = 'biscuits'

# %% [markdown]
# ## What a Variable?

# %%
#A variable is a storage location in a program where we can keep data

# %% [markdown]
# ## Why do we need variables?

# %%
#To store information we want to use later
# To make program flexible(we can change values without rewritting everything)

# %%
a = 11
#a += 2  
a = a + 2
print(a)
# Out:
# 13

# %%
#To keep our codes organized and readable

# %% [markdown]
# ## Declaring and Assigning Variables

# %%
#Examples

# %%
name = "Beryl" #here, we are assigning the value Beryl to variable called name
age = 20 #we are assigning the value 20 to a variable called age
height = 1.75 # assigning value 1.75m to a variable called height.

# %% [markdown]
# ### Rules for Naming Variables

# %% [markdown]
# #### 1.Must start with a letter or underscore(_)

# %%
#Examples

# %%
food = "ugali"  #lower-case
Food = "Sukumawiki" #capitalization
FOOD = "Nanasi" #Upper-case

print(food)
# Out:
# ugali

# %%
print(Food)
# Out:
# Sukumawiki

# %%
print(FOOD.upper())   #{} []  ()
# Out:
# NANASI

# %%
_name = "Isack"
_food = "maandazi"
_first_born = "Jemimah"
_last_born ="Sonko"

print(_name)
# Out:
# Isack

# %%
print(_food)
# Out:
# maandazi

# %%
print(_first_born)
# Out:
# Jemimah

# %%
print(_last_born)
# Out:
# Sonko

# %%
_first_name = 'Mitchelle'
print(_first_name)
# Out:
# Mitchelle

# %% [markdown]
# ## 2.Can contain letters ,numbers, or undescores

# %%
#Example

# %%
name1 = "Jordan"
name_1 = "Tomboy"
_name_1 = "Mishra"
print(name1)
# Out:
# Jordan

# %%
print(name_1)
# Out:
# Tomboy

# %%
print(_name_1)
# Out:
# Mishra

# %% [markdown]
# ## 3.CANNOT USE SPACES(my age is wrong,instead use my_age)

# %%
name_1 = "Jordan"
my_age = 79
print(name_1)
print(my_age)
# Out:
# Jordan
# 79

# %% [markdown]
# ## 4.WE CANNOT USE RESERVED KEYWORDS(e.g, print,if,while, class,True,False)

# %%
#Built-in functions

# %%
#print,

# %%
#print = "Isack"
#name 
#if 
#while
#len
#type

# %% [markdown]
# ## 5.Case-Sensitive

# %%
age = 21
AGE = 20
Age = 22
#AGE != age
print(age)
print(AGE)
print(Age)
# Out:
# 21
# 20
# 22

# %% [markdown]
# ## Types of Data a Variable can HOLD

# %%
#Numbers(integers-whole numbers)
#Decimal numbers - floats
# Text(Strings) 
#Boolean(True/False)

# %% [markdown]
# ## Numbers

# %%
marks = 90 #this is an integer
pi = 3.14 #this is a float
r = 2
area = pi*r**2
print(area)
# Out:
# 12.56

# %% [markdown]
# # String

# %%
city = "Kendu Bay"
print(city)
# Out:
# Kendu Bay

# %%
name = "Ribashongilogasheshiakili"
print(name)
# Out:
# Ribashongilogasheshiakili

# %%
_last_name = "Olang'o"
print(_last_name)
# Out:
# Olang'o

# %%
_last_name = 'Olang\'o'        
print(_last_name)
# Out:
# Olang'o

# %% [markdown]
# # Boolean(True/False)

# %%
is_student = True
print(is_student)
# Out:
# True

# %% [markdown]
# # Examples

# %%
#storing information 
student_name = "Stefan"
student_age = 145
student_grade = "A"

#Using the variables
print(student_name, "is" ,student_age, "years old and got grade", student_grade)
# Out:
# Stefan is 145 years old and got grade A

# %% [markdown]
# ## CLASS ACTIVTY

# %%
# Create 4 variables using different rules for each and print them

# %%
# Make a statement from the variables and print

# %%
Food = "Omena"
nutrient_1 = "protein"
_age = 15
is_agreed = True
print("Is", Food, "a good source of", nutrient_1, "for children under ", age, 'years old',"?",is_agreed)
# Out:
# Is Omena a good source of protein for children under  21 years old ? True

# %% [markdown]
# ## Irene's work

# %%
name_1 = "dog"
age = 5
day = "Tuesday"
print("The", name_1, "turns", age, "on", day)
# Out:
# The dog turns 5 on Tuesday

# %% [markdown]
# ## Milton's Work

# %%
Runners_name = "Eliud Kipchoge"
Runners_Distance = 20
Running_time = 2

print(Runners_name, "was awarded for running",Runners_Distance,"km under", Running_time," hours during the world championship")
# Out:
# Eliud Kipchoge was awarded for running 20 km under 2  hours during the world championship
