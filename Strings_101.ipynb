# %% [markdown]
# # What is a string?

# %%
# A string is a sequence of characters(letters, numbers, symbols)
# In Python ,strings are written inside quotes( ' ' or " ")

# %%
name =  'Python'
print(name)
# Out:
# Python

# %%
greeting = "Hello"
print(greeting)
# Out:
# Hello

# %%
# Example on how to print
'hello world!'
# Out:
# 'hello world!'

# %%
"hello world"
# Out:
# 'hello world'

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # Creating Strings

# %%
# Single quote : 'Hello'
# Double quotes: : "Hello"
# Triple quotes(for multi-line)

# %%
details = """My name is Isack
,I study at the Technical University of Kenya
,I live in Nairobi."""

print(details)
# Out:
# My name is Isack,I study at the Technical University of Kenya,I live in Nairobi.

# %%
details = "My name is Isack,I study at the Technical University of Kenya,I live in Nairobi."
print(details)
# Out:
# My name is Isack,I study at the Technical University of Kenya,I live in Nairobi.

# %% [markdown]
# # String Operations

# %% [markdown]
# ## Concatenation (+) - joining of strings

# %%
firstname = "Isack"
lastname = "Muchiri"

print(firstname + " " + lastname)
# Out:
# Isack Muchiri

# %% [markdown]
# ## Repetitition of strings(*) - repeating strings

# %%
laugh = "ha" * 3
print(laugh)
# Out:
# hahaha

# %%
beat = "du" * 5
print(beat)
# Out:
# dududududu

# %% [markdown]
# # * Asterisk

# %%
 2 ** 3
# Out:
# 8

# %% [markdown]
# # String Indexing and Slicing

# %%
# Strings are indexed(positions start at 0 )

# %%
word = "Python"
len(word)
# Out:
# 6

# %%
print(word[0])
# Out:
# P

# %%
print(word[1])
# Out:
# y

# %%
print(word[5])
# Out:
# n

# %%
print(word[-1])
# Out:
# n

# %% [markdown]
# ## Slicing

# %%
statment = "Python is Fun"
print(word3[0:6])
# Out:
# Python

# %%
# python has 6 characters
# indexing begins from 0

# %% [markdown]
# ## String Formatting(f-strings)

# %%
name = 'Olang\'o'
age = 79
print(f"My name is {name}, I am {age} years old.")
# Out:
# My name is Olang'o, I am 79 years old.
